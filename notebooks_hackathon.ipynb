# %%
#Set up the notebook to be able to fetch from the google bucket
import os

BILLING_PROJECT_ID = os.environ['WORKSPACE_NAMESPACE']
WORKSPACE = os.environ['WORKSPACE_NAME']
bucket = os.environ['WORKSPACE_BUCKET']

# %%
#Copy files from the google bucket to the notebook's VM
# !gcloud storage cp $bucket/* .
# Out:
# Copying gs://fc-6432ab48-f392-48b4-bfc0-43d3f3ad482e/COSMIC_noncoding_MCF7.tsv to file://./COSMIC_noncoding_MCF7.tsv
# Copying gs://fc-6432ab48-f392-48b4-bfc0-43d3f3ad482e/CRISPR_DepMap_Chronos.tsv to file://./CRISPR_DepMap_Chronos.tsv
# Copying gs://fc-6432ab48-f392-48b4-bfc0-43d3f3ad482e/CRISPR_DepMap_Chronos_MCF7.tsv to file://./CRISPR_DepMap_Chronos_MCF7.tsv
# Copying gs://fc-6432ab48-f392-48b4-bfc0-43d3f3ad482e/CRISPR_DepMap_DEMETER.tsv to file://./CRISPR_DepMap_DEMETER.tsv
# Copying gs://fc-6432ab48-f392-48b4-bfc0-43d3f3ad482e/EFO_0000305_associations_export.tsv to file://./EFO_0000305_associations_export.tsv
# Copying gs://fc-6432ab48-f392-48b4-bfc0-43d3f3ad482e/OmicsSomaticMutations.csv to file://./OmicsSomaticMutations.csv
# Copying gs://fc-6432ab48-f392-48b4-bfc0-43d3f3ad482e/domains.bedpe to file://./domains.bedpe
# Copying gs://fc-6432ab48-f392-48b4-bfc0-43d3f3ad482e/loops.bedpe to file://./loops.bedpe
# WARNING: Omitting gs://fc-6432ab48-f392-48b4-bfc0-43d3f3ad482e/notebooks/ because it is a container, and recursion is not enabled.
# WARNING: Omitting gs://fc-6432ab48-f392-48b4-bfc0-43d3f3ad482e/uploads/ because it is a container, and recursion is not enabled.
#   Completed files 8/8 | 872.6MiB/872.6MiB | 128.2MiB/s
#
# Average throughput: 145.9MiB/s

# %%
import csv
from collections import defaultdict


"""
Transforms a tsv file into a dictionary of the form chromosome:row

Input:
file - a tsv that includes columns "#chr1" representing a chromosome, "x1" representing
a position on the chromosome and "x2" representing a position on the chromosome greater than
or equal to "x1"

Returns:
A dictionary with "#chr1" as the key and the input row as value, with values "x1" and "x2"
tranformed into ints
"""
def format_bedpe(file):            
    with open(file, "r") as f1:
        tsv_file = csv.DictReader(f1, delimiter="\t")
        dictified_tsv = defaultdict(list)
        count = 1
        for row in tsv_file:
            if row['x1']:
                row['x1'] = int(row['x1'])
                row['x2'] = int(row['x2'])
                dictified_tsv[row['#chr1']].append(row)
        return dictified_tsv


"""
Matches regions of a chromsome to regions that overlap in the input data

Input:
chrom - a chromosome in the format "chrNUM"
begin - a number representing position on the chromosome
end - a number representing position on the chromosome - should be greater than or equal to begin
input_data - a dictionary of the form chromosome:row, where row is a dictionary that includes 
keys "x1" - a number representing position on the chromsome and "x2" - a number representing
position on the chromsome, greater than or equal to x1

Returns:
A dictionary of the form gene:results, where results is a list of the rows from input_data that
are on the same chromosome of the gene and whose x-values overlap the gene's coordinates

"""
def get_match(chrom, begin, end, input_data):
    c1s = input_data[chrom]
    results = []
    for row in c1s:
        if not((begin <= row['x1'] and end <= row['x2']) or (begin >= row['x1'] and end >= row['x2'])):
            results.append(row)
    return results

# %%
#Import file
loops_dictified = format_bedpe("loops.bedpe")

#Define genes of interest

CRISPR = {
    "ESR1": ("chr6", 151656691, 152129619),
    "BCAS1": ("chr20", 53936777, 54070594),
    "BMP7": ("chr20", 57168753, 57266641),
    "FOXA1": ("chr14", 37589552, 37596059),
    "GATA3": ("chr10", 8045378, 8075198),
    "GABARAPL2": ("chr16", 75566375, 75577881),
    "TBX2": ("chr17", 61399843, 61409466),
    "TFAP2C": ("chr20", 56629306, 56639283),
    "NTNG1": ("chr1", 107140007, 107484923),
    "TCHHL1": ("chr1", 152084141, 152089064)
}

RNAi = {
    "MDM4": ("chr1", 204516379, 204558120),
    "ESR1": ("chr6", 151656691, 152129619),
    "KDM1A": ("chr1", 23019443, 23083689),
    "SAFB": ("chr19", 5623035, 5668478),
    "MDM2": ("chr12", 68808177, 68845544),
    "CCND1": ("chr11", 69641156, 69654474),
    "CDK4": ("chr12", 57747727, 57756013),
    "STK24": ("chr13", 98445185, 98577940),
    "CYP2A6": ("chr19", 40843541, 40850447),
    "RPS16": ("chr19", 39433137, 39435949)
}

# %%
#Check genes for matches in the loops file
crispr_results = CRISPR.copy()
for gene, coords in CRISPR.items():
    crispr_results[gene] = get_match(coords[0], coords[1], coords[2], loops_dictified)

RNAi_results = RNAi.copy()
for gene, coords in RNAi.items():
    RNAi_results[gene] = get_match(coords[0], coords[1], coords[2], loops_dictified)

# %%
"""
Transforms a tsv into a dictionary keyed by chromosome

Input:
association_file - a tsv file that contains a column "locations" with format
#chromosome:location

Returns
a dictionary with the chromosome as the key and the entire row as the value
"""
def group_associations(association_file):
    with open(association_file, "r") as file:
        association_tsv = csv.DictReader(file, delimiter="\t")
        association_dict = defaultdict(list)
        for line in association_tsv:
            location = line['locations'].split(":")
            chrom = location[0]
            association_dict[chrom].append(line)
    return association_dict


"""
Finds matches between ranges and a given location

Input:
associations - a dictionary of the form chromosome:associations, where chromosome is a number
and associations is list of dictionaries that include a key "locations" with value of the form "chromosome:position"
ex: # {1: [{riskAllele: rs123, locations: 1:123, ...}], 2: {riskAllele: rs456, locations: 2:456, ...}}
genes - a dictionary of the form gene:loops, where loops is a list of dictionaries that
include: key "chr2"/value chromosome of the form "chrNUM", key "y1"/value position, key "y2"/value position
ex: {ESR1: [{chr2: chr6, 'y1': '151','y2': '152',...}, {chr2: chr6, 'y1': '153','y2': '157',...}], 'MDM4': [...]}

Returns:
A dictionary with genes as keys and a list of tuples as values. 
The tuples include the data from the associations in the first spot, and data from genes in the second
"""
def cross_reference_associations(associations, genes):
    assoc_results = defaultdict(list)
    for chrom, locs in associations.items():
        for gene, results in genes.items():
            #chrom: 1
            #locs: [{..locations: 1:123},{..}]
            #gene: ESR1
            #results: [{chr2: chr6, 'y1': '151','y2': '152',...}, {chr2: chr6, 'y1': '153','y2': '157',...},...]
            for result in results:
                if result['chr2'].split('chr')[1] == chrom:
                    for loc in locs:
                        try:
                            location = int(loc['locations'].split(":")[1])
                            if location >= int(result['y1']) and location <= int(result['y2']):
                                assoc_results[gene].append((result,locs))
                        except:
                            pass
    return assoc_results

# %%
"""
Turns a messy pile of data into readable results that we care about

Input:
results - A dictionary with genes as keys and a list of tuples as values. 
The tuples include the data from the associations in the first spot, and data from genes in the second

Returns:
A dictionary with genes as keys and a list of dictionaries as values.
The dictionaries include chromosome and position, riskAllele, pValue
"""
def massage_results(results):
    end_dict = defaultdict(list)
    for gene, tups in results.items():
        for tup in tups:
            for assoc in tup[1]:
                end_dict[gene].append({'location': assoc['locations'], 'riskAllele': assoc['riskAllele'], 'pValue': assoc['pValue']})
    return end_dict

# %%
#See if any of the locations in the assoc_file are contained in the y's of the
#results from above

assoc_file = "EFO_0000305_associations_export.tsv"
assoc_dict = group_associations(assoc_file)

crispr_assoc = cross_reference_associations(assoc_dict, crispr_results)
rnai_assoc = cross_reference_associations(assoc_dict, RNAi_results)

# %%
crispr_end = massage_results(crispr_assoc)
rnai_end = massage_results(rnai_assoc)

merged_results = rnai_end | crispr_end

# %%
merged_results
# Out:
# defaultdict(list,
#             {'ESR1': [{'location': '6:151621059',
#                'riskAllele': 'rs3757322-G',
#                'pValue': '6E-9'},
#               {'location': '6:151631197',
#                'riskAllele': 'rs9397437-A',
#                'pValue': '5E-9'},
#               {'location': '6:151666222',
#                'riskAllele': 'rs9383938-T',
#                'pValue': '3E-9'},
#               {'location': '6:33272092',
#                'riskAllele': 'rs17215231-C',
#                'pValue': '9E-13'},
#               {'location': '6:151592978',
#                'riskAllele': 'rs3757318-A',
#                'pValue': '9E-6'},
#               {'location': '6:135969804',
#                'riskAllele': 'rs11154838-C',
#                'pValue': '1E-6'},
#               {'location': '6:151623479',
#                'riskAllele': 'rs9383936-A',
#                'pValue': '1E-10'},
#               {'location': '6:151627231',
#                'riskAllele': 'rs2046210-A',
#                'pValue': '1E-9'},
#               {'location': '6:151597721',
#                'riskAllele': 'rs12662670-?',
#                'pValue': '9E-15'},
#               {'location': '6:151625017',
#                'riskAllele': 'rs11155804-?',
#                'pValue': '8E-18'},
#               {'location': '6:152115881',
#                'riskAllele': 'rs2747652-C',
#                'pValue': '2E-18'},
#               {'location': '6:151621059',
#                'riskAllele': 'rs3757322-G',
#                'pValue': '3E-31'},
#               {'location': '6:130027974',
#                'riskAllele': 'rs6569648-T',
#                'pValue': '4E-8'},
#               {'location': '6:81418669',
#                'riskAllele': 'rs17529111-C',
#                'pValue': '2E-6'},
#               {'location': '6:151631197',
#                'riskAllele': 'rs9397437-A',
#                'pValue': '3E-40'},
#               {'location': '6:80398959',
#                'riskAllele': 'rs4604234-C',
#                'pValue': '6E-6'},
#               {'location': '6:28387058',
#                'riskAllele': 'rs67981811-C',
#                'pValue': '5E-42'},
#               {'location': '6:25874195',
#                'riskAllele': 'rs13198474-G',
#                'pValue': '2E-25'},
#               {'location': '6:26463347',
#                'riskAllele': 'rs13195402-G',
#                'pValue': '3E-39'},
#               {'location': '6:27541714',
#                'riskAllele': 'rs13195636-A',
#                'pValue': '1E-43'},
#               {'location': '6:29176755',
#                'riskAllele': 'rs9257566-C',
#                'pValue': '6E-40'},
#               {'location': '6:36681143',
#                'riskAllele': 'rs3176337-A',
#                'pValue': '1E-8'},
#               {'location': '6:151703850',
#                'riskAllele': 'rs851982-T',
#                'pValue': '2E-11'},
#               {'location': '6:151705939',
#                'riskAllele': 'rs851981-A',
#                'pValue': '4E-10'},
#               {'location': '6:28958443',
#                'riskAllele': 'rs9257408-C',
#                'pValue': '5E-7'},
#               {'location': '6:13722291',
#                'riskAllele': 'rs204247-G',
#                'pValue': '3E-7'},
#               {'location': '6:81418669',
#                'riskAllele': 'rs17529111-C',
#                'pValue': '5E-7'},
#               {'location': '6:151597721',
#                'riskAllele': 'rs12662670-G',
#                'pValue': '1E-18'},
#               {'location': '6:28958443',
#                'riskAllele': 'rs9257408-C',
#                'pValue': '5E-8'},
#               {'location': '6:1318643',
#                'riskAllele': 'rs11242675-T',
#                'pValue': '1E-7'},
#               {'location': '6:13722291',
#                'riskAllele': 'rs204247-G',
#                'pValue': '4E-10'},
#               {'location': '6:81418669',
#                'riskAllele': 'rs17529111-C',
#                'pValue': '2E-10'},
#               {'location': '6:151597721',
#                'riskAllele': 'rs12662670-G',
#                'pValue': '7E-27'},
#               {'location': '6:151627231',
#                'riskAllele': 'rs2046210-A',
#                'pValue': '6E-24'},
#               {'location': '6:127279485',
#                'riskAllele': 'rs2180341-G',
#                'pValue': '3E-8'},
#               {'location': '6:151627231',
#                'riskAllele': 'rs2046210-C',
#                'pValue': '5E-9'},
#               {'location': '6:151627231',
#                'riskAllele': 'rs2046210-A',
#                'pValue': '2E-15'},
#               {'location': '6:151592978',
#                'riskAllele': 'rs3757318-A',
#                'pValue': '3E-6'},
#               {'location': '6:151618215',
#                'riskAllele': 'rs3734805-C',
#                'pValue': '1E-7'},
#               {'location': '6:19443704',
#                'riskAllele': 'rs16882214-?',
#                'pValue': '2E-6'},
#               {'location': '6:81483392',
#                'riskAllele': 'rs17530068-C',
#                'pValue': '3E-6'},
#               {'location': '6:151627231',
#                'riskAllele': 'rs2046210-A',
#                'pValue': '5E-16'},
#               {'location': '6:151592978',
#                'riskAllele': 'rs3757318-A',
#                'pValue': '2E-21'},
#               {'location': '6:13722291',
#                'riskAllele': 'rs204247-G',
#                'pValue': '8E-9'},
#               {'location': '6:81483392',
#                'riskAllele': 'rs17530068-G',
#                'pValue': '8E-9'},
#               {'location': '6:1318643',
#                'riskAllele': 'rs11242675-T',
#                'pValue': '7E-9'},
#               {'location': '6:149287738',
#                'riskAllele': 'rs9485372-G',
#                'pValue': '4E-12'},
#               {'location': '6:151974478',
#                'riskAllele': 'rs9383951-G',
#                'pValue': '2E-6'},
#               {'location': '6:151592978',
#                'riskAllele': 'rs3757318-A',
#                'pValue': '1E-6'},
#               {'location': '6:151627231',
#                'riskAllele': 'rs2046210-A',
#                'pValue': '7E-15'},
#               {'location': '6:151597721',
#                'riskAllele': 'rs12662670-?',
#                'pValue': '1E-19'},
#               {'location': '6:151625017',
#                'riskAllele': 'rs11155804-?',
#                'pValue': '4E-28'},
#               {'location': '6:151628177',
#                'riskAllele': 'rs7763637-A',
#                'pValue': '5E-13'},
#               {'location': '6:21903302',
#                'riskAllele': 'rs7760611-C',
#                'pValue': '2E-9'},
#               {'location': '6:21903302',
#                'riskAllele': 'rs7760611-?',
#                'pValue': '2E-9'},
#               {'location': '6:151632992',
#                'riskAllele': 'rs6900157-C',
#                'pValue': '5E-10'},
#               {'location': '6:152034021',
#                'riskAllele': 'rs9479169-C',
#                'pValue': '1E-7'},
#               {'location': '6:151666222',
#                'riskAllele': 'rs9383938-T',
#                'pValue': '2E-10'},
#               {'location': '6:81483392',
#                'riskAllele': 'rs17530068-C',
#                'pValue': '3E-7'},
#               {'location': '6:151633699',
#                'riskAllele': 'rs140068132-A',
#                'pValue': '9E-18'},
#               {'location': '6:19134974',
#                'riskAllele': 'rs116095464-T',
#                'pValue': '6E-9'},
#               {'location': '6:13722291',
#                'riskAllele': 'rs204247-A',
#                'pValue': '3E-14'},
#               {'location': '6:16399326',
#                'riskAllele': 'rs3819405-T',
#                'pValue': '6E-7'},
#               {'location': '6:20621007',
#                'riskAllele': 'rs2223621-T',
#                'pValue': '2E-8'},
#               {'location': '6:28958443',
#                'riskAllele': 'rs9257408-C',
#                'pValue': '3E-7'},
#               {'location': '6:80384570',
#                'riskAllele': 'rs12207986-A',
#                'pValue': '2E-10'},
#               {'location': '6:81418669',
#                'riskAllele': 'rs17529111-T',
#                'pValue': '3E-10'},
#               {'location': '6:130027974',
#                'riskAllele': 'rs6569648-T',
#                'pValue': '2E-12'},
#               {'location': '6:151687847',
#                'riskAllele': 'rs2941741-A',
#                'pValue': '8E-10'},
#               {'location': '6:152115881',
#                'riskAllele': 'rs2747652-T',
#                'pValue': '6E-28'},
#               {'location': '6:149287738',
#                'riskAllele': 'rs9485372-G',
#                'pValue': '8E-12'},
#               {'location': '6:151627231',
#                'riskAllele': 'rs2046210-A',
#                'pValue': '3E-74'},
#               {'location': '6:19134974',
#                'riskAllele': 'rs116095464-C',
#                'pValue': '4E-9'},
#               {'location': '6:36795636',
#                'riskAllele': 'rs72856431-T',
#                'pValue': '9E-7'},
#               {'location': '6:130027974',
#                'riskAllele': 'rs6569648-T',
#                'pValue': '8E-10'},
#               {'location': '6:151621059',
#                'riskAllele': 'rs3757322-G',
#                'pValue': '3E-12'},
#               {'location': '6:151631197',
#                'riskAllele': 'rs9397437-A',
#                'pValue': '6E-8'},
#               {'location': '6:157009956',
#                'riskAllele': 'rs140842923-T',
#                'pValue': '3E-6'},
#               {'location': '6:13722291',
#                'riskAllele': 'rs204247-G',
#                'pValue': '8E-13'},
#               {'location': '6:151631197',
#                'riskAllele': 'rs9397437-A',
#                'pValue': '5E-54'},
#               {'location': '6:156907180',
#                'riskAllele': 'rs28648619-G',
#                'pValue': '5E-6'},
#               {'location': '6:30365728',
#                'riskAllele': 'rs3094054-T',
#                'pValue': '1E-7'},
#               {'location': '6:30793795',
#                'riskAllele': 'rs3129984-T',
#                'pValue': '8E-6'},
#               {'location': '6:29509637',
#                'riskAllele': 'rs1233480-T',
#                'pValue': '5E-8'},
#               {'location': '6:26463346',
#                'riskAllele': 'rs13195401-T',
#                'pValue': '2E-9'},
#               {'location': '6:25874195',
#                'riskAllele': 'rs13198474-A',
#                'pValue': '2E-7'},
#               {'location': '6:28364364',
#                'riskAllele': 'rs13214023-A',
#                'pValue': '1E-9'},
#               {'location': '6:152115881',
#                'riskAllele': 'rs2747652-C',
#                'pValue': '1E-26'},
#               {'location': '6:28958443',
#                'riskAllele': 'rs9257408-C',
#                'pValue': '7E-8'},
#               {'location': '6:20621007',
#                'riskAllele': 'rs2223621-T',
#                'pValue': '3E-10'},
#               {'location': '6:26680470',
#                'riskAllele': 'rs71557345-G',
#                'pValue': '4E-10'},
#               {'location': '6:130027974',
#                'riskAllele': 'rs6569648-T',
#                'pValue': '3E-12'},
#               {'location': '6:16399326',
#                'riskAllele': 'rs3819405-C',
#                'pValue': '2E-8'},
#               {'location': '6:80384570',
#                'riskAllele': 'rs12207986-A',
#                'pValue': '2E-9'},
#               {'location': '6:122394099',
#                'riskAllele': 'rs74392007-T',
#                'pValue': '3E-7'},
#               {'location': '6:151859461',
#                'riskAllele': 'rs78796841-G',
#                'pValue': '8E-7'},
#               {'location': '6:84379128',
#                'riskAllele': 'rs7768862-A',
#                'pValue': '6E-6'},
#               {'location': '6:1319077',
#                'riskAllele': 'rs80199833-T',
#                'pValue': '7E-6'},
#               {'location': '6:122554525',
#                'riskAllele': 'rs76092474-T',
#                'pValue': '3E-6'},
#               {'location': '6:54862053',
#                'riskAllele': 'rs924712-G',
#                'pValue': '4E-6'},
#               {'location': '6:29882943',
#                'riskAllele': 'rs1611579-C',
#                'pValue': '8E-7'},
#               {'location': '6:151621059',
#                'riskAllele': 'rs3757322-G',
#                'pValue': '3E-41'},
#               {'location': '6:149287738',
#                'riskAllele': 'rs9485372-G',
#                'pValue': '4E-6'},
#               {'location': '6:81418669',
#                'riskAllele': 'rs17529111-C',
#                'pValue': '1E-9'},
#               {'location': '6:4445101',
#                'riskAllele': 'rs145711907-T',
#                'pValue': '2E-6'},
#               {'location': '6:29107311',
#                'riskAllele': 'rs3129178-A',
#                'pValue': '6E-9'},
#               {'location': '6:29280372',
#                'riskAllele': 'rs3130834-C',
#                'pValue': '5E-9'},
#               {'location': '6:30576624',
#                'riskAllele': 'rs3132610-G',
#                'pValue': '1E-6'},
#               {'location': '6:30473526',
#                'riskAllele': 'rs3132615-T',
#                'pValue': '2E-6'},
#               {'location': '6:28594471',
#                'riskAllele': 'rs34119086-T',
#                'pValue': '8E-9'},
#               {'location': '6:27457865',
#                'riskAllele': 'rs34196306-C',
#                'pValue': '1E-9'},
#               {'location': '6:26993501',
#                'riskAllele': 'rs34546498-T',
#                'pValue': '9E-10'},
#               {'location': '6:28106103',
#                'riskAllele': 'rs34662244-A',
#                'pValue': '3E-9'},
#               {'location': '6:149265193',
#                'riskAllele': 'rs35409891-C',
#                'pValue': '3E-9'},
#               {'location': '6:21905495',
#                'riskAllele': 'rs9350395-G',
#                'pValue': '3E-7'},
#               {'location': '6:81545215',
#                'riskAllele': 'rs9361840-G',
#                'pValue': '7E-14'},
#               {'location': '6:7231610',
#                'riskAllele': 'rs9379084-A',
#                'pValue': '3E-6'},
#               {'location': '6:80496839',
#                'riskAllele': 'rs9449003-A',
#                'pValue': '3E-6'},
#               {'location': '6:20923044',
#                'riskAllele': 'rs9460578-A',
#                'pValue': '1E-6'},
#               {'location': '6:151634779',
#                'riskAllele': 'rs60954078-G',
#                'pValue': '3E-54'},
#               {'location': '6:30003183',
#                'riskAllele': 'rs3094146-C',
#                'pValue': '7E-7'},
#               {'location': '6:30107326',
#                'riskAllele': 'rs2523992-G',
#                'pValue': '2E-7'},
#               {'location': '6:29693039',
#                'riskAllele': 'rs3116813-A',
#                'pValue': '6E-7'},
#               {'location': '6:29388554',
#                'riskAllele': 'rs9257809-G',
#                'pValue': '3E-8'},
#               {'location': '6:30682249',
#                'riskAllele': 'rs9262142-A',
#                'pValue': '3E-6'},
#               {'location': '6:26175638',
#                'riskAllele': 'rs17598658-C',
#                'pValue': '2E-9'},
#               {'location': '6:80636316',
#                'riskAllele': 'rs1902066-C',
#                'pValue': '7E-6'},
#               {'location': '6:13713134',
#                'riskAllele': 'rs418053-C',
#                'pValue': '1E-13'},
#               {'location': '6:27873148',
#                'riskAllele': 'rs45509595-C',
#                'pValue': '5E-9'},
#               {'location': '6:27104763',
#                'riskAllele': 'rs55834529-G',
#                'pValue': '3E-9'},
#               {'location': '6:27307055',
#                'riskAllele': 'rs56114371-T',
#                'pValue': '2E-9'},
#               {'location': '6:99643666',
#                'riskAllele': 'rs377527229-C',
#                'pValue': '6E-6'},
#               {'location': '6:36676721',
#                'riskAllele': 'rs3829964-C',
#                'pValue': '9E-8'},
#               {'location': '6:166087862',
#                'riskAllele': 'rs113289039-AG',
#                'pValue': '3E-7'},
#               {'location': '6:43259403',
#                'riskAllele': 'rs111342015-A',
#                'pValue': '9E-8'},
#               {'location': '6:25710343',
#                'riskAllele': 'rs68006638-A',
#                'pValue': '2E-7'},
#               {'location': '6:151734843',
#                'riskAllele': 'rs6904031-T',
#                'pValue': '7E-26'},
#               {'location': '6:81677422',
#                'riskAllele': 'rs6912005-A',
#                'pValue': '2E-11'},
#               {'location': '6:20728282',
#                'riskAllele': 'rs6928012-T',
#                'pValue': '2E-6'},
#               {'location': '6:85210757',
#                'riskAllele': 'rs6934651-C',
#                'pValue': '6E-6'},
#               {'location': '6:170017397',
#                'riskAllele': 'rs6940159-C',
#                'pValue': '3E-7'},
#               {'location': '6:10456473',
#                'riskAllele': 'rs9348512-C',
#                'pValue': '4E-8'},
#               {'location': '6:151630867',
#                'riskAllele': 'rs9397436-G',
#                'pValue': '4E-18'},
#               {'location': '6:151734843',
#                'riskAllele': 'rs6904031-T',
#                'pValue': '6E-9'},
#               {'location': '6:152111767',
#                'riskAllele': 'rs910416-T',
#                'pValue': '6E-16'},
#               {'location': '6:149255943',
#                'riskAllele': 'rs7758080-G',
#                'pValue': '1E-10'},
#               {'location': '6:151628671',
#                'riskAllele': 'rs6913578-C',
#                'pValue': '2E-30'},
#               {'location': '6:151628447',
#                'riskAllele': 'rs6557160-C',
#                'pValue': '6E-17'},
#               {'location': '6:81545215',
#                'riskAllele': 'rs9361840-G',
#                'pValue': '8E-8'},
#               {'location': '6:151615542',
#                'riskAllele': 'rs6929137-?',
#                'pValue': '2E-13'},
#               {'location': '6:151630085',
#                'riskAllele': 'rs9397435-?',
#                'pValue': '4E-38'},
#               {'location': '6:6550516',
#                'riskAllele': 'rs17142289-?',
#                'pValue': '4E-6'},
#               {'location': '6:25874195',
#                'riskAllele': 'rs13198474-G',
#                'pValue': '1E-23'},
#               {'location': '6:26463347',
#                'riskAllele': 'rs13195402-G',
#                'pValue': '1E-38'},
#               {'location': '6:27541714',
#                'riskAllele': 'rs13195636-A',
#                'pValue': '4E-43'},
#               {'location': '6:28387058',
#                'riskAllele': 'rs67981811-C',
#                'pValue': '2E-41'},
#               {'location': '6:66197278',
#                'riskAllele': 'rs112319963-?',
#                'pValue': '2E-6'},
#               {'location': '6:14107800',
#                'riskAllele': 'rs71564305-?',
#                'pValue': '3E-6'},
#               {'location': '6:166308998',
#                'riskAllele': 'rs4075454-?',
#                'pValue': '5E-6'},
#               {'location': '6:36681143',
#                'riskAllele': 'rs3176337-A',
#                'pValue': '8E-11'},
#               {'location': '6:151702056',
#                'riskAllele': 'rs851984-A',
#                'pValue': '3E-23'},
#               {'location': '6:151621059',
#                'riskAllele': 'rs3757322-G',
#                'pValue': '6E-9'},
#               {'location': '6:151631197',
#                'riskAllele': 'rs9397437-A',
#                'pValue': '5E-9'},
#               {'location': '6:151666222',
#                'riskAllele': 'rs9383938-T',
#                'pValue': '3E-9'},
#               {'location': '6:33272092',
#                'riskAllele': 'rs17215231-C',
#                'pValue': '9E-13'},
#               {'location': '6:151592978',
#                'riskAllele': 'rs3757318-A',
#                'pValue': '9E-6'},
#               {'location': '6:135969804',
#                'riskAllele': 'rs11154838-C',
#                'pValue': '1E-6'},
#               {'location': '6:151623479',
#                'riskAllele': 'rs9383936-A',
#                'pValue': '1E-10'},
#               {'location': '6:151627231',
#                'riskAllele': 'rs2046210-A',
#                'pValue': '1E-9'},
#               {'location': '6:151597721',
#                'riskAllele': 'rs12662670-?',
#                'pValue': '9E-15'},
#               {'location': '6:151625017',
#                'riskAllele': 'rs11155804-?',
#                'pValue': '8E-18'},
#               {'location': '6:152115881',
#                'riskAllele': 'rs2747652-C',
#                'pValue': '2E-18'},
#               {'location': '6:151621059',
#                'riskAllele': 'rs3757322-G',
#                'pValue': '3E-31'},
#               {'location': '6:130027974',
#                'riskAllele': 'rs6569648-T',
#                'pValue': '4E-8'},
#               {'location': '6:81418669',
#                'riskAllele': 'rs17529111-C',
#                'pValue': '2E-6'},
#               {'location': '6:151631197',
#                'riskAllele': 'rs9397437-A',
#                'pValue': '3E-40'},
#               {'location': '6:80398959',
#                'riskAllele': 'rs4604234-C',
#                'pValue': '6E-6'},
#               {'location': '6:28387058',
#                'riskAllele': 'rs67981811-C',
#                'pValue': '5E-42'},
#               {'location': '6:25874195',
#                'riskAllele': 'rs13198474-G',
#                'pValue': '2E-25'},
#               {'location': '6:26463347',
#                'riskAllele': 'rs13195402-G',
#                'pValue': '3E-39'},
#               {'location': '6:27541714',
#                'riskAllele': 'rs13195636-A',
#                'pValue': '1E-43'},
#               {'location': '6:29176755',
#                'riskAllele': 'rs9257566-C',
#                'pValue': '6E-40'},
#               {'location': '6:36681143',
#                'riskAllele': 'rs3176337-A',
#                'pValue': '1E-8'},
#               {'location': '6:151703850',
#                'riskAllele': 'rs851982-T',
#                'pValue': '2E-11'},
#               {'location': '6:151705939',
#                'riskAllele': 'rs851981-A',
#                'pValue': '4E-10'},
#               {'location': '6:28958443',
#                'riskAllele': 'rs9257408-C',
#                'pValue': '5E-7'},
#               {'location': '6:13722291',
#                'riskAllele': 'rs204247-G',
#                'pValue': '3E-7'},
#               {'location': '6:81418669',
#                'riskAllele': 'rs17529111-C',
#                'pValue': '5E-7'},
#               {'location': '6:151597721',
#                'riskAllele': 'rs12662670-G',
#                'pValue': '1E-18'},
#               {'location': '6:28958443',
#                'riskAllele': 'rs9257408-C',
#                'pValue': '5E-8'},
#               {'location': '6:1318643',
#                'riskAllele': 'rs11242675-T',
#                'pValue': '1E-7'},
#               {'location': '6:13722291',
#                'riskAllele': 'rs204247-G',
#                'pValue': '4E-10'},
#               {'location': '6:81418669',
#                'riskAllele': 'rs17529111-C',
#                'pValue': '2E-10'},
#               {'location': '6:151597721',
#                'riskAllele': 'rs12662670-G',
#                'pValue': '7E-27'},
#               {'location': '6:151627231',
#                'riskAllele': 'rs2046210-A',
#                'pValue': '6E-24'},
#               {'location': '6:127279485',
#                'riskAllele': 'rs2180341-G',
#                'pValue': '3E-8'},
#               {'location': '6:151627231',
#                'riskAllele': 'rs2046210-C',
#                'pValue': '5E-9'},
#               {'location': '6:151627231',
#                'riskAllele': 'rs2046210-A',
#                'pValue': '2E-15'},
#               {'location': '6:151592978',
#                'riskAllele': 'rs3757318-A',
#                'pValue': '3E-6'},
#               {'location': '6:151618215',
#                'riskAllele': 'rs3734805-C',
#                'pValue': '1E-7'},
#               {'location': '6:19443704',
#                'riskAllele': 'rs16882214-?',
#                'pValue': '2E-6'},
#               {'location': '6:81483392',
#                'riskAllele': 'rs17530068-C',
#                'pValue': '3E-6'},
#               {'location': '6:151627231',
#                'riskAllele': 'rs2046210-A',
#                'pValue': '5E-16'},
#               {'location': '6:151592978',
#                'riskAllele': 'rs3757318-A',
#                'pValue': '2E-21'},
#               {'location': '6:13722291',
#                'riskAllele': 'rs204247-G',
#                'pValue': '8E-9'},
#               {'location': '6:81483392',
#                'riskAllele': 'rs17530068-G',
#                'pValue': '8E-9'},
#               {'location': '6:1318643',
#                'riskAllele': 'rs11242675-T',
#                'pValue': '7E-9'},
#               {'location': '6:149287738',
#                'riskAllele': 'rs9485372-G',
#                'pValue': '4E-12'},
#               {'location': '6:151974478',
#                'riskAllele': 'rs9383951-G',
#                'pValue': '2E-6'},
#               {'location': '6:151592978',
#                'riskAllele': 'rs3757318-A',
#                'pValue': '1E-6'},
#               {'location': '6:151627231',
#                'riskAllele': 'rs2046210-A',
#                'pValue': '7E-15'},
#               {'location': '6:151597721',
#                'riskAllele': 'rs12662670-?',
#                'pValue': '1E-19'},
#               {'location': '6:151625017',
#                'riskAllele': 'rs11155804-?',
#                'pValue': '4E-28'},
#               {'location': '6:151628177',
#                'riskAllele': 'rs7763637-A',
#                'pValue': '5E-13'},
#               {'location': '6:21903302',
#                'riskAllele': 'rs7760611-C',
#                'pValue': '2E-9'},
#               {'location': '6:21903302',
#                'riskAllele': 'rs7760611-?',
#                'pValue': '2E-9'},
#               {'location': '6:151632992',
#                'riskAllele': 'rs6900157-C',
#                'pValue': '5E-10'},
#               {'location': '6:152034021',
#                'riskAllele': 'rs9479169-C',
#                'pValue': '1E-7'},
#               {'location': '6:151666222',
#                'riskAllele': 'rs9383938-T',
#                'pValue': '2E-10'},
#               {'location': '6:81483392',
#                'riskAllele': 'rs17530068-C',
#                'pValue': '3E-7'},
#               {'location': '6:151633699',
#                'riskAllele': 'rs140068132-A',
#                'pValue': '9E-18'},
#               {'location': '6:19134974',
#                'riskAllele': 'rs116095464-T',
#                'pValue': '6E-9'},
#               {'location': '6:13722291',
#                'riskAllele': 'rs204247-A',
#                'pValue': '3E-14'},
#               {'location': '6:16399326',
#                'riskAllele': 'rs3819405-T',
#                'pValue': '6E-7'},
#               {'location': '6:20621007',
#                'riskAllele': 'rs2223621-T',
#                'pValue': '2E-8'},
#               {'location': '6:28958443',
#                'riskAllele': 'rs9257408-C',
#                'pValue': '3E-7'},
#               {'location': '6:80384570',
#                'riskAllele': 'rs12207986-A',
#                'pValue': '2E-10'},
#               {'location': '6:81418669',
#                'riskAllele': 'rs17529111-T',
#                'pValue': '3E-10'},
#               {'location': '6:130027974',
#                'riskAllele': 'rs6569648-T',
#                'pValue': '2E-12'},
#               {'location': '6:151687847',
#                'riskAllele': 'rs2941741-A',
#                'pValue': '8E-10'},
#               {'location': '6:152115881',
#                'riskAllele': 'rs2747652-T',
#                'pValue': '6E-28'},
#               {'location': '6:149287738',
#                'riskAllele': 'rs9485372-G',
#                'pValue': '8E-12'},
#               {'location': '6:151627231',
#                'riskAllele': 'rs2046210-A',
#                'pValue': '3E-74'},
#               {'location': '6:19134974',
#                'riskAllele': 'rs116095464-C',
#                'pValue': '4E-9'},
#               {'location': '6:36795636',
#                'riskAllele': 'rs72856431-T',
#                'pValue': '9E-7'},
#               {'location': '6:130027974',
#                'riskAllele': 'rs6569648-T',
#                'pValue': '8E-10'},
#               {'location': '6:151621059',
#                'riskAllele': 'rs3757322-G',
#                'pValue': '3E-12'},
#               {'location': '6:151631197',
#                'riskAllele': 'rs9397437-A',
#                'pValue': '6E-8'},
#               {'location': '6:157009956',
#                'riskAllele': 'rs140842923-T',
#                'pValue': '3E-6'},
#               {'location': '6:13722291',
#                'riskAllele': 'rs204247-G',
#                'pValue': '8E-13'},
#               {'location': '6:151631197',
#                'riskAllele': 'rs9397437-A',
#                'pValue': '5E-54'},
#               {'location': '6:156907180',
#                'riskAllele': 'rs28648619-G',
#                'pValue': '5E-6'},
#               {'location': '6:30365728',
#                'riskAllele': 'rs3094054-T',
#                'pValue': '1E-7'},
#               {'location': '6:30793795',
#                'riskAllele': 'rs3129984-T',
#                'pValue': '8E-6'},
#               {'location': '6:29509637',
#                'riskAllele': 'rs1233480-T',
#                'pValue': '5E-8'},
#               {'location': '6:26463346',
#                'riskAllele': 'rs13195401-T',
#                'pValue': '2E-9'},
#               {'location': '6:25874195',
#                'riskAllele': 'rs13198474-A',
#                'pValue': '2E-7'},
#               {'location': '6:28364364',
#                'riskAllele': 'rs13214023-A',
#                'pValue': '1E-9'},
#               {'location': '6:152115881',
#                'riskAllele': 'rs2747652-C',
#                'pValue': '1E-26'},
#               {'location': '6:28958443',
#                'riskAllele': 'rs9257408-C',
#                'pValue': '7E-8'},
#               {'location': '6:20621007',
#                'riskAllele': 'rs2223621-T',
#                'pValue': '3E-10'},
#               {'location': '6:26680470',
#                'riskAllele': 'rs71557345-G',
#                'pValue': '4E-10'},
#               {'location': '6:130027974',
#                'riskAllele': 'rs6569648-T',
#                'pValue': '3E-12'},
#               {'location': '6:16399326',
#                'riskAllele': 'rs3819405-C',
#                'pValue': '2E-8'},
#               {'location': '6:80384570',
#                'riskAllele': 'rs12207986-A',
#                'pValue': '2E-9'},
#               {'location': '6:122394099',
#                'riskAllele': 'rs74392007-T',
#                'pValue': '3E-7'},
#               {'location': '6:151859461',
#                'riskAllele': 'rs78796841-G',
#                'pValue': '8E-7'},
#               {'location': '6:84379128',
#                'riskAllele': 'rs7768862-A',
#                'pValue': '6E-6'},
#               {'location': '6:1319077',
#                'riskAllele': 'rs80199833-T',
#                'pValue': '7E-6'},
#               {'location': '6:122554525',
#                'riskAllele': 'rs76092474-T',
#                'pValue': '3E-6'},
#               {'location': '6:54862053',
#                'riskAllele': 'rs924712-G',
#                'pValue': '4E-6'},
#               {'location': '6:29882943',
#                'riskAllele': 'rs1611579-C',
#                'pValue': '8E-7'},
#               {'location': '6:151621059',
#                'riskAllele': 'rs3757322-G',
#                'pValue': '3E-41'},
#               {'location': '6:149287738',
#                'riskAllele': 'rs9485372-G',
#                'pValue': '4E-6'},
#               {'location': '6:81418669',
#                'riskAllele': 'rs17529111-C',
#                'pValue': '1E-9'},
#               {'location': '6:4445101',
#                'riskAllele': 'rs145711907-T',
#                'pValue': '2E-6'},
#               {'location': '6:29107311',
#                'riskAllele': 'rs3129178-A',
#                'pValue': '6E-9'},
#               {'location': '6:29280372',
#                'riskAllele': 'rs3130834-C',
#                'pValue': '5E-9'},
#               {'location': '6:30576624',
#                'riskAllele': 'rs3132610-G',
#                'pValue': '1E-6'},
#               {'location': '6:30473526',
#                'riskAllele': 'rs3132615-T',
#                'pValue': '2E-6'},
#               {'location': '6:28594471',
#                'riskAllele': 'rs34119086-T',
#                'pValue': '8E-9'},
#               {'location': '6:27457865',
#                'riskAllele': 'rs34196306-C',
#                'pValue': '1E-9'},
#               {'location': '6:26993501',
#                'riskAllele': 'rs34546498-T',
#                'pValue': '9E-10'},
#               {'location': '6:28106103',
#                'riskAllele': 'rs34662244-A',
#                'pValue': '3E-9'},
#               {'location': '6:149265193',
#                'riskAllele': 'rs35409891-C',
#                'pValue': '3E-9'},
#               {'location': '6:21905495',
#                'riskAllele': 'rs9350395-G',
#                'pValue': '3E-7'},
#               {'location': '6:81545215',
#                'riskAllele': 'rs9361840-G',
#                'pValue': '7E-14'},
#               {'location': '6:7231610',
#                'riskAllele': 'rs9379084-A',
#                'pValue': '3E-6'},
#               {'location': '6:80496839',
#                'riskAllele': 'rs9449003-A',
#                'pValue': '3E-6'},
#               {'location': '6:20923044',
#                'riskAllele': 'rs9460578-A',
#                'pValue': '1E-6'},
#               {'location': '6:151634779',
#                'riskAllele': 'rs60954078-G',
#                'pValue': '3E-54'},
#               {'location': '6:30003183',
#                'riskAllele': 'rs3094146-C',
#                'pValue': '7E-7'},
#               {'location': '6:30107326',
#                'riskAllele': 'rs2523992-G',
#                'pValue': '2E-7'},
#               {'location': '6:29693039',
#                'riskAllele': 'rs3116813-A',
#                'pValue': '6E-7'},
#               {'location': '6:29388554',
#                'riskAllele': 'rs9257809-G',
#                'pValue': '3E-8'},
#               {'location': '6:30682249',
#                'riskAllele': 'rs9262142-A',
#                'pValue': '3E-6'},
#               {'location': '6:26175638',
#                'riskAllele': 'rs17598658-C',
#                'pValue': '2E-9'},
#               {'location': '6:80636316',
#                'riskAllele': 'rs1902066-C',
#                'pValue': '7E-6'},
#               {'location': '6:13713134',
#                'riskAllele': 'rs418053-C',
#                'pValue': '1E-13'},
#               {'location': '6:27873148',
#                'riskAllele': 'rs45509595-C',
#                'pValue': '5E-9'},
#               {'location': '6:27104763',
#                'riskAllele': 'rs55834529-G',
#                'pValue': '3E-9'},
#               {'location': '6:27307055',
#                'riskAllele': 'rs56114371-T',
#                'pValue': '2E-9'},
#               {'location': '6:99643666',
#                'riskAllele': 'rs377527229-C',
#                'pValue': '6E-6'},
#               {'location': '6:36676721',
#                'riskAllele': 'rs3829964-C',
#                'pValue': '9E-8'},
#               {'location': '6:166087862',
#                'riskAllele': 'rs113289039-AG',
#                'pValue': '3E-7'},
#               {'location': '6:43259403',
#                'riskAllele': 'rs111342015-A',
#                'pValue': '9E-8'},
#               {'location': '6:25710343',
#                'riskAllele': 'rs68006638-A',
#                'pValue': '2E-7'},
#               {'location': '6:151734843',
#                'riskAllele': 'rs6904031-T',
#                'pValue': '7E-26'},
#               {'location': '6:81677422',
#                'riskAllele': 'rs6912005-A',
#                'pValue': '2E-11'},
#               {'location': '6:20728282',
#                'riskAllele': 'rs6928012-T',
#                'pValue': '2E-6'},
#               {'location': '6:85210757',
#                'riskAllele': 'rs6934651-C',
#                'pValue': '6E-6'},
#               {'location': '6:170017397',
#                'riskAllele': 'rs6940159-C',
#                'pValue': '3E-7'},
#               {'location': '6:10456473',
#                'riskAllele': 'rs9348512-C',
#                'pValue': '4E-8'},
#               {'location': '6:151630867',
#                'riskAllele': 'rs9397436-G',
#                'pValue': '4E-18'},
#               {'location': '6:151734843',
#                'riskAllele': 'rs6904031-T',
#                'pValue': '6E-9'},
#               {'location': '6:152111767',
#                'riskAllele': 'rs910416-T',
#                'pValue': '6E-16'},
#               {'location': '6:149255943',
#                'riskAllele': 'rs7758080-G',
#                'pValue': '1E-10'},
#               {'location': '6:151628671',
#                'riskAllele': 'rs6913578-C',
#                'pValue': '2E-30'},
#               {'location': '6:151628447',
#                'riskAllele': 'rs6557160-C',
#                'pValue': '6E-17'},
#               {'location': '6:81545215',
#                'riskAllele': 'rs9361840-G',
#                'pValue': '8E-8'},
#               {'location': '6:151615542',
#                'riskAllele': 'rs6929137-?',
#                'pValue': '2E-13'},
#               {'location': '6:151630085',
#                'riskAllele': 'rs9397435-?',
#                'pValue': '4E-38'},
#               {'location': '6:6550516',
#                'riskAllele': 'rs17142289-?',
#                'pValue': '4E-6'},
#               {'location': '6:25874195',
#                'riskAllele': 'rs13198474-G',
#                'pValue': '1E-23'},
#               {'location': '6:26463347',
#                'riskAllele': 'rs13195402-G',
#                'pValue': '1E-38'},
#               {'location': '6:27541714',
#                'riskAllele': 'rs13195636-A',
#                'pValue': '4E-43'},
#               {'location': '6:28387058',
#                'riskAllele': 'rs67981811-C',
#                'pValue': '2E-41'},
#               {'location': '6:66197278',
#                'riskAllele': 'rs112319963-?',
#                'pValue': '2E-6'},
#               {'location': '6:14107800',
#                'riskAllele': 'rs71564305-?',
#                'pValue': '3E-6'},
#               {'location': '6:166308998',
#                'riskAllele': 'rs4075454-?',
#                'pValue': '5E-6'},
#               {'location': '6:36681143',
#                'riskAllele': 'rs3176337-A',
#                'pValue': '8E-11'},
#               {'location': '6:151702056',
#                'riskAllele': 'rs851984-A',
#                'pValue': '3E-23'},
#               {'location': '6:151621059',
#                'riskAllele': 'rs3757322-G',
#                'pValue': '6E-9'},
#               {'location': '6:151631197',
#                'riskAllele': 'rs9397437-A',
#                'pValue': '5E-9'},
#               {'location': '6:151666222',
#                'riskAllele': 'rs9383938-T',
#                'pValue': '3E-9'},
#               {'location': '6:33272092',
#                'riskAllele': 'rs17215231-C',
#                'pValue': '9E-13'},
#               {'location': '6:151592978',
#                'riskAllele': 'rs3757318-A',
#                'pValue': '9E-6'},
#               {'location': '6:135969804',
#                'riskAllele': 'rs11154838-C',
#                'pValue': '1E-6'},
#               {'location': '6:151623479',
#                'riskAllele': 'rs9383936-A',
#                'pValue': '1E-10'},
#               {'location': '6:151627231',
#                'riskAllele': 'rs2046210-A',
#                'pValue': '1E-9'},
#               {'location': '6:151597721',
#                'riskAllele': 'rs12662670-?',
#                'pValue': '9E-15'},
#               {'location': '6:151625017',
#                'riskAllele': 'rs11155804-?',
#                'pValue': '8E-18'},
#               {'location': '6:152115881',
#                'riskAllele': 'rs2747652-C',
#                'pValue': '2E-18'},
#               {'location': '6:151621059',
#                'riskAllele': 'rs3757322-G',
#                'pValue': '3E-31'},
#               {'location': '6:130027974',
#                'riskAllele': 'rs6569648-T',
#                'pValue': '4E-8'},
#               {'location': '6:81418669',
#                'riskAllele': 'rs17529111-C',
#                'pValue': '2E-6'},
#               {'location': '6:151631197',
#                'riskAllele': 'rs9397437-A',
#                'pValue': '3E-40'},
#               {'location': '6:80398959',
#                'riskAllele': 'rs4604234-C',
#                'pValue': '6E-6'},
#               {'location': '6:28387058',
#                'riskAllele': 'rs67981811-C',
#                'pValue': '5E-42'},
#               {'location': '6:25874195',
#                'riskAllele': 'rs13198474-G',
#                'pValue': '2E-25'},
#               {'location': '6:26463347',
#                'riskAllele': 'rs13195402-G',
#                'pValue': '3E-39'},
#               {'location': '6:27541714',
#                'riskAllele': 'rs13195636-A',
#                'pValue': '1E-43'},
#               {'location': '6:29176755',
#                'riskAllele': 'rs9257566-C',
#                'pValue': '6E-40'},
#               {'location': '6:36681143',
#                'riskAllele': 'rs3176337-A',
#                'pValue': '1E-8'},
#               {'location': '6:151703850',
#                'riskAllele': 'rs851982-T',
#                'pValue': '2E-11'},
#               {'location': '6:151705939',
#                'riskAllele': 'rs851981-A',
#                'pValue': '4E-10'},
#               {'location': '6:28958443',
#                'riskAllele': 'rs9257408-C',
#                'pValue': '5E-7'},
#               {'location': '6:13722291',
#                'riskAllele': 'rs204247-G',
#                'pValue': '3E-7'},
#               {'location': '6:81418669',
#                'riskAllele': 'rs17529111-C',
#                'pValue': '5E-7'},
#               {'location': '6:151597721',
#                'riskAllele': 'rs12662670-G',
#                'pValue': '1E-18'},
#               {'location': '6:28958443',
#                'riskAllele': 'rs9257408-C',
#                'pValue': '5E-8'},
#               {'location': '6:1318643',
#                'riskAllele': 'rs11242675-T',
#                'pValue': '1E-7'},
#               {'location': '6:13722291',
#                'riskAllele': 'rs204247-G',
#                'pValue': '4E-10'},
#               {'location': '6:81418669',
#                'riskAllele': 'rs17529111-C',
#                'pValue': '2E-10'},
#               {'location': '6:151597721',
#                'riskAllele': 'rs12662670-G',
#                'pValue': '7E-27'},
#               {'location': '6:151627231',
#                'riskAllele': 'rs2046210-A',
#                'pValue': '6E-24'},
#               {'location': '6:127279485',
#                'riskAllele': 'rs2180341-G',
#                'pValue': '3E-8'},
#               {'location': '6:151627231',
#                'riskAllele': 'rs2046210-C',
#                'pValue': '5E-9'},
#               {'location': '6:151627231',
#                'riskAllele': 'rs2046210-A',
#                'pValue': '2E-15'},
#               {'location': '6:151592978',
#                'riskAllele': 'rs3757318-A',
#                'pValue': '3E-6'},
#               {'location': '6:151618215',
#                'riskAllele': 'rs3734805-C',
#                'pValue': '1E-7'},
#               {'location': '6:19443704',
#                'riskAllele': 'rs16882214-?',
#                'pValue': '2E-6'},
#               {'location': '6:81483392',
#                'riskAllele': 'rs17530068-C',
#                'pValue': '3E-6'},
#               {'location': '6:151627231',
#                'riskAllele': 'rs2046210-A',
#                'pValue': '5E-16'},
#               {'location': '6:151592978',
#                'riskAllele': 'rs3757318-A',
#                'pValue': '2E-21'},
#               {'location': '6:13722291',
#                'riskAllele': 'rs204247-G',
#                'pValue': '8E-9'},
#               {'location': '6:81483392',
#                'riskAllele': 'rs17530068-G',
#                'pValue': '8E-9'},
#               {'location': '6:1318643',
#                'riskAllele': 'rs11242675-T',
#                'pValue': '7E-9'},
#               {'location': '6:149287738',
#                'riskAllele': 'rs9485372-G',
#                'pValue': '4E-12'},
#               {'location': '6:151974478',
#                'riskAllele': 'rs9383951-G',
#                'pValue': '2E-6'},
#               {'location': '6:151592978',
#                'riskAllele': 'rs3757318-A',
#                'pValue': '1E-6'},
#               {'location': '6:151627231',
#                'riskAllele': 'rs2046210-A',
#                'pValue': '7E-15'},
#               {'location': '6:151597721',
#                'riskAllele': 'rs12662670-?',
#                'pValue': '1E-19'},
#               {'location': '6:151625017',
#                'riskAllele': 'rs11155804-?',
#                'pValue': '4E-28'},
#               {'location': '6:151628177',
#                'riskAllele': 'rs7763637-A',
#                'pValue': '5E-13'},
#               {'location': '6:21903302',
#                'riskAllele': 'rs7760611-C',
#                'pValue': '2E-9'},
#               {'location': '6:21903302',
#                'riskAllele': 'rs7760611-?',
#                'pValue': '2E-9'},
#               {'location': '6:151632992',
#                'riskAllele': 'rs6900157-C',
#                'pValue': '5E-10'},
#               {'location': '6:152034021',
#                'riskAllele': 'rs9479169-C',
#                'pValue': '1E-7'},
#               {'location': '6:151666222',
#                'riskAllele': 'rs9383938-T',
#                'pValue': '2E-10'},
#               {'location': '6:81483392',
#                'riskAllele': 'rs17530068-C',
#                'pValue': '3E-7'},
#               {'location': '6:151633699',
#                'riskAllele': 'rs140068132-A',
#                'pValue': '9E-18'},
#               {'location': '6:19134974',
#                'riskAllele': 'rs116095464-T',
#                'pValue': '6E-9'},
#               {'location': '6:13722291',
#                'riskAllele': 'rs204247-A',
#                'pValue': '3E-14'},
#               {'location': '6:16399326',
#                'riskAllele': 'rs3819405-T',
#                'pValue': '6E-7'},
#               {'location': '6:20621007',
#                'riskAllele': 'rs2223621-T',
#                'pValue': '2E-8'},
#               {'location': '6:28958443',
#                'riskAllele': 'rs9257408-C',
#                'pValue': '3E-7'},
#               {'location': '6:80384570',
#                'riskAllele': 'rs12207986-A',
#                'pValue': '2E-10'},
#               {'location': '6:81418669',
#                'riskAllele': 'rs17529111-T',
#                'pValue': '3E-10'},
#               {'location': '6:130027974',
#                'riskAllele': 'rs6569648-T',
#                'pValue': '2E-12'},
#               {'location': '6:151687847',
#                'riskAllele': 'rs2941741-A',
#                'pValue': '8E-10'},
#               {'location': '6:152115881',
#                'riskAllele': 'rs2747652-T',
#                'pValue': '6E-28'},
#               {'location': '6:149287738',
#                'riskAllele': 'rs9485372-G',
#                'pValue': '8E-12'},
#               {'location': '6:151627231',
#                'riskAllele': 'rs2046210-A',
#                'pValue': '3E-74'},
#               {'location': '6:19134974',
#                'riskAllele': 'rs116095464-C',
#                'pValue': '4E-9'},
#               {'location': '6:36795636',
#                'riskAllele': 'rs72856431-T',
#                'pValue': '9E-7'},
#               {'location': '6:130027974',
#                'riskAllele': 'rs6569648-T',
#                'pValue': '8E-10'},
#               {'location': '6:151621059',
#                'riskAllele': 'rs3757322-G',
#                'pValue': '3E-12'},
#               {'location': '6:151631197',
#                'riskAllele': 'rs9397437-A',
#                'pValue': '6E-8'},
# ...
#                'pValue': '2E-7'},
#               {'location': '1:149955122',
#                'riskAllele': 'rs12048493-C',
#                'pValue': '2E-9'},
#               {'location': '1:241870961',
#                'riskAllele': 'rs72755295-G',
#                'pValue': '3E-7'},
#               {'location': '1:10506158',
#                'riskAllele': 'rs616488-A',
#                'pValue': '9E-9'},
#               {'location': '1:113905767',
#                'riskAllele': 'rs11552449-T',
#                'pValue': '6E-7'},
#               {'location': '1:121538815',
#                'riskAllele': 'rs11249433-G',
#                'pValue': '4E-20'},
#               {'location': '1:145790097',
#                'riskAllele': 'rs12405132-C',
#                'pValue': '8E-9'},
#               {'location': '1:149955122',
#                'riskAllele': 'rs12048493-C',
#                'pValue': '1E-9'},
#               {'location': '1:241870961',
#                'riskAllele': 'rs72755295-G',
#                'pValue': '2E-8'},
#               {'location': '1:10506158',
#                'riskAllele': 'rs616488-A',
#                'pValue': '4E-11'},
#               {'location': '1:113905767',
#                'riskAllele': 'rs11552449-T',
#                'pValue': '3E-9'},
#               {'location': '1:121538815',
#                'riskAllele': 'rs11249433-G',
#                'pValue': '3E-27'},
#               {'location': '1:8334176,1:8335500,1:8330828,1:8326670,1:8335381',
#                'riskAllele': 'rs12711517-?,rs7535752-?,rs2289731-?,rs9628987-?,rs2305016-?',
#                'pValue': '5E-6'},
#               {'location': '1:8335500,1:8326670',
#                'riskAllele': 'rs7535752-?,rs9628987-?',
#                'pValue': '5E-6'},
#               {'location': '1:204546897',
#                'riskAllele': 'rs2290854-A',
#                'pValue': '1E-7'},
#               {'location': '1:121538815',
#                'riskAllele': 'rs11249433-C',
#                'pValue': '7E-10'},
#               {'location': '1:10506158',
#                'riskAllele': 'rs616488-A',
#                'pValue': '1E-8'},
#               {'location': '1:204549714',
#                'riskAllele': 'rs4245739-?',
#                'pValue': '2E-12'},
#               {'location': '1:202218048',
#                'riskAllele': 'rs6678914-?',
#                'pValue': '1E-8'},
#               {'location': '1:121538815',
#                'riskAllele': 'rs11249433-G',
#                'pValue': '2E-26'},
#               {'location': '1:10506158',
#                'riskAllele': 'rs616488-A',
#                'pValue': '2E-10'},
#               {'location': '1:113905767',
#                'riskAllele': 'rs11552449-T',
#                'pValue': '2E-8'},
#               {'location': '1:114128347',
#                'riskAllele': 'rs2774307-?',
#                'pValue': '8E-6'},
#               {'location': '1:164720525',
#                'riskAllele': 'rs1387389-?',
#                'pValue': '4E-6'},
#               {'location': '1:87313534',
#                'riskAllele': 'rs12118297-G',
#                'pValue': '4E-8'},
#               {'location': '1:10503552',
#                'riskAllele': 'rs10864459-?',
#                'pValue': '5E-10'},
#               {'location': '1:204549714',
#                'riskAllele': 'rs4245739-?',
#                'pValue': '8E-18'},
#               {'location': '1:202209914',
#                'riskAllele': 'rs17489300-?',
#                'pValue': '2E-8'},
#               {'location': '1:109680280',
#                'riskAllele': 'rs5776993-C',
#                'pValue': '3E-8'},
#               {'location': '1:119942712',
#                'riskAllele': 'rs6697258-?',
#                'pValue': '2E-15'},
#               {'location': '1:120044057',
#                'riskAllele': 'rs150157076-?',
#                'pValue': '1E-10'},
#               {'location': '1:200372918',
#                'riskAllele': 'rs6677545-?',
#                'pValue': '4E-8'},
#               {'location': '1:156183252',
#                'riskAllele': 'rs11264454-?',
#                'pValue': '2E-8'},
#               {'location': '1:87385737',
#                'riskAllele': 'rs11161996-C',
#                'pValue': '8E-7'},
#               {'location': '1:210196877',
#                'riskAllele': 'rs11119434-T',
#                'pValue': '8E-7'},
#               {'location': '1:217047232',
#                'riskAllele': 'rs11117758-A',
#                'pValue': '4E-9'},
#               {'location': '1:40914768',
#                'riskAllele': 'rs4233486-T',
#                'pValue': '2E-8'},
#               {'location': '1:50380361',
#                'riskAllele': 'rs140850326-CAAAGGGCAAGATCTCCTTTTT',
#                'pValue': '3E-7'},
#               {'location': '1:113905767',
#                'riskAllele': 'rs11552449-T',
#                'pValue': '1E-9'},
#               {'location': '1:145790097',
#                'riskAllele': 'rs12405132-T',
#                'pValue': '5E-9'},
#               {'location': '1:149955122',
#                'riskAllele': 'rs12048493-A',
#                'pValue': '4E-14'},
#               {'location': '1:155176305',
#                'riskAllele': 'rs4971059-A',
#                'pValue': '2E-10'},
#               {'location': '1:203797203',
#                'riskAllele': 'rs4951011-G',
#                'pValue': '2E-8'},
#               {'location': '1:10506158',
#                'riskAllele': 'rs616488-A',
#                'pValue': '2E-23'},
#               {'location': '1:18480845',
#                'riskAllele': 'rs2992756-T',
#                'pValue': '5E-17'},
#               {'location': '1:46135245',
#                'riskAllele': 'rs1707302-A',
#                'pValue': '3E-10'},
#               {'location': '1:87691240',
#                'riskAllele': 'rs17426269-A',
#                'pValue': '2E-8'},
#               {'location': '1:117687599',
#                'riskAllele': 'rs7529522-T',
#                'pValue': '5E-10'},
#               {'location': '1:121538815',
#                'riskAllele': 'rs11249433-A',
#                'pValue': '8E-54'},
#               {'location': '1:203797203',
#                'riskAllele': 'rs4951011-G',
#                'pValue': '9E-9'},
#               {'location': '1:117687599',
#                'riskAllele': 'rs7529522-C',
#                'pValue': '2E-10'},
#               {'location': '1:201468704',
#                'riskAllele': 'rs35383942-T',
#                'pValue': '4E-13'},
#               {'location': '1:17380437',
#                'riskAllele': 'rs1924553-G',
#                'pValue': '5E-7'},
#               {'location': '1:10637822',
#                'riskAllele': 'rs199867187-G',
#                'pValue': '1E-6'},
#               {'location': '1:155928952',
#                'riskAllele': 'rs11406084-CA',
#                'pValue': '7E-6'},
#               {'location': '1:87963341',
#                'riskAllele': 'rs11583393-A',
#                'pValue': '4E-8'},
#               {'location': '1:45918469',
#                'riskAllele': 'rs12077974-A',
#                'pValue': '2E-7'},
#               {'location': '1:155587180',
#                'riskAllele': 'rs12091730-A',
#                'pValue': '2E-10'},
#               {'location': '1:216850159',
#                'riskAllele': 'rs12095761-G',
#                'pValue': '3E-6'},
#               {'location': '1:91555907',
#                'riskAllele': 'rs12134245-T',
#                'pValue': '4E-6'},
#               {'location': '1:113630788',
#                'riskAllele': 'rs1230666-G',
#                'pValue': '4E-10'},
#               {'location': '1:87384812',
#                'riskAllele': 'rs1415174-C',
#                'pValue': '6E-6'},
#               {'location': '1:10506158',
#                'riskAllele': 'rs616488-A',
#                'pValue': '5E-20'},
#               {'location': '1:145790097',
#                'riskAllele': 'rs12405132-C',
#                'pValue': '6E-10'},
#               {'location': '1:149955122',
#                'riskAllele': 'rs12048493-C',
#                'pValue': '9E-14'},
#               {'location': '1:113905767',
#                'riskAllele': 'rs11552449-T',
#                'pValue': '5E-11'},
#               {'location': '1:213369363',
#                'riskAllele': 'rs17020562-C',
#                'pValue': '7E-8'},
#               {'location': '1:213369363',
#                'riskAllele': 'rs17020562-C',
#                'pValue': '3E-7'},
#               {'location': '1:40914768',
#                'riskAllele': 'rs4233486-T',
#                'pValue': '9E-9'},
#               {'location': '1:46135245',
#                'riskAllele': 'rs1707302-G',
#                'pValue': '3E-8'},
#               {'location': '1:87691240',
#                'riskAllele': 'rs17426269-A',
#                'pValue': '2E-8'},
#               {'location': '1:155176305',
#                'riskAllele': 'rs4971059-A',
#                'pValue': '5E-11'},
#               {'location': '1:18480845',
#                'riskAllele': 'rs2992756-T',
#                'pValue': '2E-15'},
#               {'location': '1:41671640',
#                'riskAllele': 'rs79724016-T',
#                'pValue': '4E-8'},
#               {'location': '1:217047232',
#                'riskAllele': 'rs11117758-G',
#                'pValue': '4E-9'},
#               {'location': '1:50380361',
#                'riskAllele': 'rs140850326-CAAAGGGCAAGATCTCCTTTTT',
#                'pValue': '4E-8'},
#               {'location': '1:155302483',
#                'riskAllele': 'rs7524950-T',
#                'pValue': '3E-9'},
#               {'location': '1:41821259',
#                'riskAllele': 'rs78295797-A',
#                'pValue': '9E-6'},
#               {'location': '1:113903258',
#                'riskAllele': 'rs7513707-A',
#                'pValue': '2E-11'},
#               {'location': '1:45688904',
#                'riskAllele': 'rs10683143-A',
#                'pValue': '2E-6'},
#               {'location': '1:118488075',
#                'riskAllele': 'rs10923574-C',
#                'pValue': '4E-7'},
#               {'location': '1:42592453',
#                'riskAllele': 'rs113319441-T',
#                'pValue': '6E-6'},
#               {'location': '1:121695219',
#                'riskAllele': 'rs149253773-T',
#                'pValue': '6E-40'},
#               {'location': '1:64370963',
#                'riskAllele': 'rs1514964-C',
#                'pValue': '9E-6'},
#               {'location': '1:145730328',
#                'riskAllele': 'rs1552172-A',
#                'pValue': '1E-8'},
#               {'location': '1:121538815',
#                'riskAllele': 'rs11249433-G',
#                'pValue': '2E-52'},
#               {'location': '1:241870961',
#                'riskAllele': 'rs72755295-G',
#                'pValue': '2E-14'},
#               {'location': '1:45548287',
#                'riskAllele': 'rs144366570-ATT',
#                'pValue': '2E-7'},
#               {'location': '1:203832121',
#                'riskAllele': 'rs59867004-C',
#                'pValue': '1E-10'},
#               {'location': '1:155697170',
#                'riskAllele': 'rs348196-C',
#                'pValue': '2E-8'},
#               {'location': '1:119894128',
#                'riskAllele': 'rs35273427-C',
#                'pValue': '2E-7'},
#               {'location': '1:149811268',
#                'riskAllele': 'rs57324102-A',
#                'pValue': '6E-6'},
#               {'location': '1:109680280',
#                'riskAllele': 'rs5776993-C',
#                'pValue': '2E-7'},
#               {'location': '1:207761719',
#                'riskAllele': 'rs5780403-CA',
#                'pValue': '9E-6'},
#               {'location': '1:168127440',
#                'riskAllele': 'rs60504827-T',
#                'pValue': '2E-7'},
#               {'location': '1:51001425',
#                'riskAllele': 'rs56168262-C',
#                'pValue': '2E-8'},
#               {'location': '1:177930963',
#                'riskAllele': 'rs575908-C',
#                'pValue': '3E-6'},
#               {'location': '1:100414772',
#                'riskAllele': 'rs612683-T',
#                'pValue': '3E-7'},
#               {'location': '1:8035440',
#                'riskAllele': 'rs225132-G',
#                'pValue': '3E-6'},
#               {'location': '1:10535965',
#                'riskAllele': 'rs2506889-T',
#                'pValue': '2E-20'},
#               {'location': '1:207903511',
#                'riskAllele': 'rs2724379-C',
#                'pValue': '2E-7'},
#               {'location': '1:41532093',
#                'riskAllele': 'rs181270898-A',
#                'pValue': '5E-7'},
#               {'location': '1:119254406',
#                'riskAllele': 'rs185028854-A',
#                'pValue': '7E-6'},
#               {'location': '1:172361919',
#                'riskAllele': 'rs1894633-G',
#                'pValue': '2E-6'},
#               {'location': '1:118111143',
#                'riskAllele': 'rs1962373-A',
#                'pValue': '1E-6'},
#               {'location': '1:120948545',
#                'riskAllele': 'rs200087884-T',
#                'pValue': '7E-7'},
#               {'location': '1:203938990',
#                'riskAllele': 'rs2810650-G',
#                'pValue': '3E-9'},
#               {'location': '1:186763038',
#                'riskAllele': 'rs56160832-A',
#                'pValue': '5E-6'},
#               {'location': '1:120018691',
#                'riskAllele': 'rs372562666-G',
#                'pValue': '6E-27'},
#               {'location': '1:145607339',
#                'riskAllele': 'rs368032757-G',
#                'pValue': '5E-6'},
#               {'location': '1:146069686',
#                'riskAllele': 'rs368121891-A',
#                'pValue': '9E-8'},
#               {'location': '1:121121848',
#                'riskAllele': 'rs369304377-G',
#                'pValue': '2E-29'},
#               {'location': '1:155446537',
#                'riskAllele': 'rs10796944-A',
#                'pValue': '7E-10'},
#               {'location': '1:149934520',
#                'riskAllele': 'rs11205303-C',
#                'pValue': '1E-14'},
#               {'location': '1:156183252',
#                'riskAllele': 'rs11264454-G',
#                'pValue': '7E-7'},
#               {'location': '1:119716347',
#                'riskAllele': 'rs666930-C',
#                'pValue': '5E-8'},
#               {'location': '1:7857016',
#                'riskAllele': 'rs707475-A',
#                'pValue': '1E-7'},
#               {'location': '1:10370245',
#                'riskAllele': 'rs187373836-A',
#                'pValue': '5E-7'},
#               {'location': '1:201468704',
#                'riskAllele': 'rs35383942-T',
#                'pValue': '6E-7'},
#               {'location': '1:121538815',
#                'riskAllele': 'rs11249433-G',
#                'pValue': '9E-13'},
#               {'location': '1:87980553',
#                'riskAllele': 'rs17130230-A',
#                'pValue': '3E-8'},
#               {'location': '1:121538815',
#                'riskAllele': 'rs11249433-G',
#                'pValue': '8E-9'},
#               {'location': '1:149934520',
#                'riskAllele': 'rs11205303-C',
#                'pValue': '5E-7'},
#               {'location': '1:109637134',
#                'riskAllele': 'rs17024629-T',
#                'pValue': '3E-8'},
#               {'location': '1:109637134',
#                'riskAllele': 'rs17024629-T',
#                'pValue': '1E-6'},
#               {'location': '1:10536284',
#                'riskAllele': 'rs12375-?',
#                'pValue': '1E-5'},
#               {'location': '1:121538815',
#                'riskAllele': 'rs11249433-?',
#                'pValue': '5E-8'},
#               {'location': '1:213850882',
#                'riskAllele': 'rs4342822-G',
#                'pValue': '7E-9'},
#               {'location': '1:109687477',
#                'riskAllele': 'rs4147562-A',
#                'pValue': '3E-9'},
#               {'location': '1:241860596',
#                'riskAllele': 'rs4149909-A',
#                'pValue': '9E-15'},
#               {'location': '1:16013277',
#                'riskAllele': 'rs1763604-C',
#                'pValue': '7E-9'},
#               {'location': '1:155016057',
#                'riskAllele': 'rs77548871-C',
#                'pValue': '5E-9'}]})

# %%
merged_results_file = open("riskAlleles.txt", "a")
for gene, results in merged_results.items():
#     merged_results_file.write(gene)
#     merged_results_file.write(str(results))
    merged_results_file.write(gene)
    for result in results:
        merged_results_file.write(str(result))
merged_results_file.close()

# %%
# !gcloud storage cp "riskAlleles.txt" $bucket
# Out:
# Copying file://riskAlleles.txt to gs://fc-6432ab48-f392-48b4-bfc0-43d3f3ad482e/riskAlleles.txt
#   Completed files 1/1 | 90.4kiB/90.4kiB

# %%
"""
Finds matches on position and notes whether riskAllele = genomic mut allele

Input:
filtered_results - A dictionary with genes as keys and a list of dictionaries as values.
The dictionaries include chromosome and position, riskAllele, pValue
mutations - a list of dictionaries that include columns "CHROMSOME", "GENOME_START", "GENOME_STOP" and "GENOMIC_MUT_ALLELE"

Returns:
A dictionary with genes as keys and values that are lists of tuples of the form
(match, result, mut) where match is True/False indicating whether the riskAllele from the filtered results
matches the genomic mutation allele, result is the entire row from the filtered results,
and mut is the entire row from the mutations list
"""
def match_allele(filtered_results, mutations):
    matches = defaultdict(list)
    for gene, results in filtered_results.items():
        for result in results:
            for mut in mutations:
                locations = result['location'].split(",")
                for loc in locations:
                    chrom, pos = loc.split(':')
                    if chrom == mut['CHROMOSOME'] and (pos == mut['GENOME_START'] or pos == mut['GENOME_STOP']):
                        print("match found")
                        allele = result['riskAllele'].split('-')[1]
                        match = allele != '?' and allele == mut['GENOMIC_MUT_ALLELE']
                        matches[gene].append((match, result, mut))
    return matches

# %%
file = "COSMIC_noncoding_MCF7.tsv"

def transform_mutations(file):
    mutations = []
    with open(file, "r") as f1:
        mutation_tsv = csv.DictReader(f1, delimiter="\t")
        for line in mutation_tsv:
            mutations.append(line)
    return mutations

# %%
matches = match_allele(merged_results, mutations)

# %%
matches.items()
# Out:
# dict_items([])

# %%
domains_dictified = format_bedpe("domains.bedpe")
crispr_results2 = CRISPR.copy()
for gene, coords in CRISPR.items():
    crispr_results2[gene] = get_match(coords[0], coords[1], coords[2], domains_dictified)

RNAi_results2 = RNAi.copy()
for gene, coords in RNAi.items():
    RNAi_results2[gene] = get_match(coords[0], coords[1], coords[2], domains_dictified)

crispr_assoc2 = cross_reference_associations(assoc_dict, crispr_results2)
rnai_assoc2 = cross_reference_associations(assoc_dict, RNAi_results2)

crispr_end2 = massage_results(crispr_assoc2)
rnai_end2 = massage_results(rnai_assoc2)

merged_results2 = rnai_end2 | crispr_end2

matches2 = match_allele(merged_results2, mutations)

# %%
"""
Inputs:
contact domains - file identifying locations of high interaction
gene positions - genes of interest and their positions
associations file - regions of interest
noncoding file - more regions to match
"""
def pipeline(contact_domains, gene_pos, associations_file, noncoding_file):
    domains = format_bedpe(contact_domains)
    gene_results = gene_pos.copy()
    for gene, coords in gene_pos.items():
        gene_results[gene] = get_match(coords[0], coords[1], coords[2], domains)
    
    assoc_dict = group_associations(associations_file)
    gene_assoc = cross_reference_associations(assoc_dict, gene_results)
    
    gene_assoc_reformat = massage_results(gene_assoc)
    
    mutations = transform_mutations(noncoding_file)

    matches = match_allele(gene_assoc_reformat, mutations)
    
    return matches

# %%
pipeline("domains.bedpe", RNAi, "EFO_0000305_associations_export.tsv", "COSMIC_noncoding_MCF7.tsv")
# Out:
# defaultdict(list, {})
